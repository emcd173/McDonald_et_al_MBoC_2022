# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib_venn import venn3
from venn import venn
from venn import pseudovenn

# %%
data = pd.read_csv('6-Gene-lists-venndiagram-12-2-20.csv')

# %%
data
# Out:
#      WT DMSO  WT VX809 P67L DMSO P67L VX809 G85E DMSO G85E VX809 L206W DMSO  \
# 0       CFTR      CFTR      CFTR       CFTR      CFTR       CFTR       CFTR
# 1          0         0         0          0         0          0          0
# 2        NaN       NaN       NaN        NaN       NaN        NaN        NaN
# 3        NaN       NaN       NaN        NaN       NaN        NaN        NaN
# 4        AGK       AGK       AGK        AGK       AGK        AGK        AGK
# ...      ...       ...       ...        ...       ...        ...        ...
# 3321     NaN  SERPINH1  SERPINH1   SERPINH1       NaN        NaN        NaN
# 3322     NaN    SPATA5    SPATA5     SPATA5       NaN        NaN        NaN
# 3323     NaN       NaN     GSTK1        NaN       NaN        NaN        NaN
# 3324     NaN       NaN       NaN        NaN       NaN        NaN        NaN
# 3325     NaN       NaN       NaN        NaN       NaN        NaN        NaN
#
#      L206W VX809 F508del DMSO F508del VX809
# ...

# %%
data2 = data[['WT DMSO','WT VX809','P67L DMSO', 'P67L VX809']]

# %%
data2 = data[['WT DMSO','WT VX809','F508del DMSO','F508del VX809']]

# %%
data2 = data[['WT DMSO','WT VX809','L206W DMSO','L206W VX809']]

# %%
data2 = data[['WT DMSO','WT VX809','G85E DMSO','G85E VX809']]

# %%
data2 = data[['P67L DMSO', 'P67L VX809','L206W DMSO','L206W VX809']]

# %%
data2 = data[['P67L DMSO', 'P67L VX809','F508del DMSO','F508del VX809']]

# %%
data2 = data[['P67L DMSO', 'P67L VX809','G85E DMSO','G85E VX809']]

# %%
data2 = data[['L206W DMSO','L206W VX809', 'F508del DMSO','F508del VX809']]

# %%
data2 = data[['L206W DMSO','L206W VX809', 'G85E DMSO','G85E VX809']]

# %%
data2 = data[['F508del DMSO','F508del VX809','G85E DMSO','G85E VX809']]

# %%
dct2 = {}
for col in data2.columns:
    dct2[col] = {}
    empty_list = []
    for i in range(len(data2[col])):
        empty_list.append(data2[col][i])
        
    dct2[col] =set(empty_list)

# %%
venn(dct2, cmap="viridis")

# %%
venn(dct3, cmap="plasma")

# %%
pseudovenn(dct4, cmap="plasma")
